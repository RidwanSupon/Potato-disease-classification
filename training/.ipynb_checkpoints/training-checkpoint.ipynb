# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS=3
EPOCHS = 10

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2149 files belonging to 3 classes.
# 2025-03-09 22:45:49.336092: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
    # protibar 32 data nicche so total length hobe 32*68 = total data
# Out:
# 68

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)

    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")
    
    #print(image_batch[0].shape)
   # print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# 2025-03-09 22:46:01.204635: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# 80% ==> training
# 20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size    # 80% of 68*32
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)

# training er jonno 80% data nilam and 68 length theke 54 legth training er jonno
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)

#remaining 20% data validation & test
# Out:
# 14

# %%
val_size = 0.1    # 10% 
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)

# validation data   6*32=
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)

#test data 8*32
# Out:
# 8

# %%
# this function take the tensor flow dataset

def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size= 1000):

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int (val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.take(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 48

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# cache read the image from the disk  keep the image in memory 
# shuffle the image
# prefetch if gpu is busy then prefetch will load the next petch from ur disk
#training will fast for that

# %%
import tensorflow as tf
from tensorflow.keras import layers

IMAGE_SIZE = 224  # Adjust as needed

resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0 / 255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
])

#augmentation suppose ekta image theke ami arou generate korte pari for test purpose

# %%
# data augmentation
# keras 
# tensor flow
# data preprocessing (image)
# image rescaling / resizing

# %%
# Defining the input shape (Batch size, Image size, Image size, Number of channels)
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)  

# Defining the number of output classes (In this case, 3 classes)
n_classes = 3  

# Creating a Sequential model
model = models.Sequential([  
    resize_and_rescale,  # Resizes and rescales the image
    data_augmentation,   # Performs data augmentation to enhance generalization

    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),  # First convolutional layer (32 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # First max pooling layer (2x2 window size)

    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),  # Second convolutional layer (64 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # Second max pooling layer

    layers.Conv2D(64, (3,3), activation='relu'),  # Third convolutional layer (64 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # Third max pooling layer

    layers.Conv2D(64, (3,3), activation='relu'),  # Fourth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # Fourth max pooling layer

    layers.Conv2D(64, (3,3), activation='relu'),  # Fifth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # Fifth max pooling layer

    layers.Conv2D(64, (3,3), activation='relu'),  # Sixth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
    layers.MaxPooling2D((2,2)),  # Sixth max pooling layer

    layers.Flatten(),  # Flattens the feature map into a one-dimensional array

    layers.Dense(64, activation='relu'),  # Fully connected layer with 64 neurons and ReLU activation
    layers.Dense(n_classes, activation='softmax')  # Output layer with `n_classes` neurons and softmax activation
])

# Building the model according to the specified input shape
model.build(input_shape=input_shape)

# %%
model.summary()   # Displays the model architecture, including layer types, output shapes, and the number of parameters.
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (32, 224, 224, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (32, 224, 224, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (32, 222, 222, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (32, 111, 111, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (32, 109, 109, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (32, 54, 54, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (32, 52, 52, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (32, 26, 26, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (32, 24, 24, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (32, 12, 12, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (32, 10, 10, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (32, 5, 5, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (32, 3, 3, 64)         │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (32, 1, 1, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (32, 64)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (32, 64)               │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (32, 3)                │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 171,459 (669.76 KB)
#  Trainable params: 171,459 (669.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(  
    optimizer='adam',  # Using the Adam optimizer for efficient training  
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),  # Sparse categorical cross-entropy loss for multi-class classification  
    metrics=['accuracy']  # Tracking accuracy as the evaluation metric  
)

# %%
model.fit(  
    train_ds,  # Training dataset  
    epochs=EPOCHS,  # Number of epochs to train the model  
    batch_size=BATCH_SIZE,  # Batch size for training  
    verbose=1,  # Display training progress  
    validation_data=val_ds  # Validation dataset to evaluate performance after each epoch  
)
# Out:
# Epoch 1/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 509ms/step - accuracy: 0.4641 - loss: 0.9802 - val_accuracy: 0.4375 - val_loss: 0.8873
# Epoch 2/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 478ms/step - accuracy: 0.4620 - loss: 0.8861 - val_accuracy: 0.5833 - val_loss: 0.7890
# Epoch 3/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 484ms/step - accuracy: 0.6627 - loss: 0.6738 - val_accuracy: 0.7917 - val_loss: 0.4984
# Epoch 4/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 40s 744ms/step - accuracy: 0.8005 - loss: 0.4684 - val_accuracy: 0.8542 - val_loss: 0.3562
# Epoch 5/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 34s 631ms/step - accuracy: 0.8556 - loss: 0.3597 - val_accuracy: 0.8438 - val_loss: 0.4191
# Epoch 6/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 539ms/step - accuracy: 0.8301 - loss: 0.3989 - val_accuracy: 0.8594 - val_loss: 0.3087
# Epoch 7/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 41s 755ms/step - accuracy: 0.8780 - loss: 0.3230 - val_accuracy: 0.8698 - val_loss: 0.2985
# Epoch 8/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 715ms/step - accuracy: 0.8742 - loss: 0.3310 - val_accuracy: 0.8750 - val_loss: 0.3122
# Epoch 9/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 696ms/step - accuracy: 0.9222 - loss: 0.1834 - val_accuracy: 0.9323 - val_loss: 0.1829
# Epoch 10/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 38s 701ms/step - accuracy: 0.9122 - loss: 0.2246 - val_accuracy: 0.9271 - val_loss: 0.1449

# %%
scores = model.evaluate(test_ds)  # Evaluates the model on the test dataset and returns the loss and accuracy.
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - accuracy: 0.9605 - loss: 0.1034

# %%
history
# Out:
# import tensorflow as tf
# from tensorflow.keras import models, layers
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from tensorflow.keras import models, layers
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from tensorflow.keras import models, layers
# import matplotlib.pyplot as plt
# IMAGE_SIZE = 256
# BATCH_SIZE = 32
# CHANNELS=3
# EPOCHS = 10
# dataset = tf.keras.preprocessing.image_dataset_from_directory(
#     "PlantVillage",
#     shuffle=True,
#     image_size = (IMAGE_SIZE,IMAGE_SIZE),
#     batch_size = BATCH_SIZE
# )
# class_names = dataset.class_names
# class_names
# len(dataset)
#     # protibar 32 data nicche so total length hobe 32*68 = total data
#
# plt.figure(figsize = (10,10))
# for image_batch, label_batch in dataset.take(1):
#     print(image_batch.shape)
#
#     for i in range(12):
#         ax = plt.subplot(3,4,i+1)
#         plt.imshow(image_batch[i].numpy().astype("uint8"))
#         plt.title(class_names[label_batch[i]])
#         plt.axis("off")
#
#     #print(image_batch[0].shape)
#    # print(label_batch.numpy())
# train_size = 0.8
# len(dataset)*train_size    # 80% of 68*32
# train_ds = dataset.take(54)
# len(train_ds)
#
# # training er jonno 80% data nilam and 68 length theke 54 legth training er jonno
# test_ds = dataset.skip(54)
# len(test_ds)
#
# #remaining 20% data validation & test
# val_size = 0.1    # 10%
# len(dataset)*val_size
# val_ds = test_ds.take(6)
# len(val_ds)
#
# # validation data   6*32=
# test_ds = test_ds.skip(6)
# len(test_ds)
#
# #test data 8*32
# # this function take the tensor flow dataset
#
# def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size= 1000):
#
#     if shuffle:
#         ds = ds.shuffle(shuffle_size, seed=12)
#     ds_size = len(ds)
#     train_size = int(train_split * ds_size)
#     val_size = int (val_split * ds_size)
#     train_ds = ds.take(train_size)
#     val_ds = ds.skip(train_size).take(val_size)
#     test_ds = ds.take(train_size).skip(val_size)
#
#     return train_ds, val_ds, test_ds
# train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
# len(train_ds)
# len(val_ds)
#
# len(test_ds)
# train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
# val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
# test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
#
# # cache read the image from the disk  keep the image in memory
# # shuffle the image
# # prefetch if gpu is busy then prefetch will load the next petch from ur disk
# #training will fast for that
# import tensorflow as tf
# from tensorflow.keras import layers
#
# IMAGE_SIZE = 224  # Adjust as needed
#
# resize_and_rescale = tf.keras.Sequential([
#     layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
#     layers.Rescaling(1.0 / 255)
# ])
# data_augmentation = tf.keras.Sequential([
#     layers.RandomFlip("horizontal_and_vertical"),
#     layers.RandomRotation(0.2)
# ])
#
# #augmentation suppose ekta image theke ami arou generate korte pari for test purpose
# # Defining the input shape (Batch size, Image size, Image size, Number of channels)
# input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
#
# # Defining the number of output classes (In this case, 3 classes)
# n_classes = 3
#
# # Creating a Sequential model
# model = models.Sequential([
#     resize_and_rescale,  # Resizes and rescales the image
#     data_augmentation,   # Performs data augmentation to enhance generalization
#
#     layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),  # First convolutional layer (32 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # First max pooling layer (2x2 window size)
#
#     layers.Conv2D(64, kernel_size=(3,3), activation='relu'),  # Second convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Second max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Third convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Third max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Fourth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Fourth max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Fifth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Fifth max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Sixth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Sixth max pooling layer
#
#     layers.Flatten(),  # Flattens the feature map into a one-dimensional array
#
#     layers.Dense(64, activation='relu'),  # Fully connected layer with 64 neurons and ReLU activation
#     layers.Dense(n_classes, activation='softmax')  # Output layer with `n_classes` neurons and softmax activation
# ])
#
# # Building the model according to the specified input shape
# model.build(input_shape=input_shape)
# data_augmentation = tf.keras.Sequential([
#     layers.RandomFlip("horizontal_and_vertical"),
#     layers.RandomRotation(0.2)
# ])
#
# #augmentation suppose ekta image theke ami arou generate korte pari for test purpose
# # Defining the input shape (Batch size, Image size, Image size, Number of channels)
# input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
#
# # Defining the number of output classes (In this case, 3 classes)
# n_classes = 3
#
# # Creating a Sequential model
# model = models.Sequential([
#     resize_and_rescale,  # Resizes and rescales the image
#     data_augmentation,   # Performs data augmentation to enhance generalization
#
#     layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),  # First convolutional layer (32 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # First max pooling layer (2x2 window size)
#
#     layers.Conv2D(64, kernel_size=(3,3), activation='relu'),  # Second convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Second max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Third convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Third max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Fourth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Fourth max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Fifth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Fifth max pooling layer
#
#     layers.Conv2D(64, (3,3), activation='relu'),  # Sixth convolutional layer (64 filters, 3x3 kernel, ReLU activation)
#     layers.MaxPooling2D((2,2)),  # Sixth max pooling layer
#
#     layers.Flatten(),  # Flattens the feature map into a one-dimensional array
#
#     layers.Dense(64, activation='relu'),  # Fully connected layer with 64 neurons and ReLU activation
#     layers.Dense(n_classes, activation='softmax')  # Output layer with `n_classes` neurons and softmax activation
# ])
#
# # Building the model according to the specified input shape
# model.build(input_shape=input_shape)
# model.summary()   # Displays the model architecture, including layer types, output shapes, and the number of parameters.
# model.compile(
#     optimizer='adam',  # Using the Adam optimizer for efficient training
#     loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),  # Sparse categorical cross-entropy loss for multi-class classification
#     metrics=['accuracy']  # Tracking accuracy as the evaluation metric
# )
# model.fit(
#     train_ds,  # Training dataset
#     epochs=EPOCHS,  # Number of epochs to train the model
#     batch_size=BATCH_SIZE,  # Batch size for training
#     verbose=1,  # Display training progress
#     validation_data=val_ds  # Validation dataset to evaluate performance after each epoch
# )
# history.params
# plt.figure(figuresize=(8,8))
# plt.subplot(1, 2, 1)
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']
# loss = history.history['loss']
# val_loss = history.history['val_loss']
# history

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3 loss = history.history['loss']
#
# NameError: name 'history' is not defined

# %%
plt.figure(figuresize=(8,8))
plt.subplot(1, 2, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.figure(figuresize=(8,8))
#       2 plt.subplot(1, 2, 1)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:1042, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1032 if len(allnums) == max_open_warning >= 1:
#    1033     _api.warn_external(
#    1034         f"More than {max_open_warning} figures have been opened. "
#    1035         f"Figures created through the pyplot interface "
#    (...)
#    1039         f"Consider using `matplotlib.pyplot.close()`.",
#    1040         RuntimeWarning)
# -> 1042 manager = new_figure_manager(
#    1043     num, figsize=figsize, dpi=dpi,
#    1044     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1045     FigureClass=FigureClass, **kwargs)
#    1046 fig = manager.canvas.figure
#    1047 if fig_label:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:552, in new_figure_manager(*args, **kwargs)
#     550 """Create a new figure manager instance."""
#     551 _warn_if_gui_out_of_main_thread()
# --> 552 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:2560, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2464 def __init__(self,
#    2465              figsize=None,
#    2466              dpi=None,
#    (...)
#    2476              **kwargs
#    2477              ):
#    2478     """
#    2479     Parameters
#    2480     ----------
#    (...)
#    2558         %(Figure:kwdoc)s
#    2559     """
# -> 2560     super().__init__(**kwargs)
#    2561     self._root_figure = self
#    2562     self._layout_engine = None
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:154, in FigureBase.__init__(self, **kwargs)
#     152 self.stale = True
#     153 self.suppressComposite = None
# --> 154 self.set(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Figure.set() got an unexpected keyword argument 'figuresize'
